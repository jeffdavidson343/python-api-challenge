# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as st

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Url and units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
# List for holding reponse information
lat = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lon = []
date = []
country = []
cloudiness = []


# Loop through the list of cities and request for data on each
print("Beginning Data Retrieval")
print("--------------------------------------------")
count = 0
set = 1
for idx, city in enumerate(cities):
    count = count + 1
    # To avoid api call rate limits, get city weather data for 50 cities,
    # then sleep for 5 seconds, and then continue with next 50 cities and so on...
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
print("------------------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | magugu
# Processing Record 4 of Set 1 | invercargill
# Processing Record 5 of Set 1 | pisco
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | blackmans bay
# Processing Record 8 of Set 1 | kruisfontein
# Processing Record 9 of Set 1 | dalhousie
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | ust-nera
# Processing Record 12 of Set 1 | diamond springs
# Processing Record 13 of Set 1 | praia
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | ormara
# Processing Record 16 of Set 1 | bilibino
# Processing Record 17 of Set 1 | constantia
# Processing Record 18 of Set 1 | waitangi
# Processing Record 19 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 20 of Set 1 | margaret river
# Processing Record 21 of Set 1 | luena
# Processing Record 22 of Set 1 | lata
# Processing Record 23 of Set 1 | flying fish cove
# Processing Record 24 of Set 1 | kidal
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | fort bragg
# Processing Record 28 of Set 1 | smithers
# Processing Record 29 of Set 1 | colonia menno
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | san jose del guaviare
# Processing Record 32 of Set 1 | chonchi
# Processing Record 33 of Set 1 | praia da vitoria
# Processing Record 34 of Set 1 | shamkhor
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | grytviken
# Processing Record 38 of Set 1 | guiuan
# Processing Record 39 of Set 1 | ust'-ilimsk
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | baotou
# Processing Record 44 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 45 of Set 1 | edinburgh of the seven seas
# Processing Record 46 of Set 1 | moree
# Processing Record 47 of Set 1 | tura
# Processing Record 48 of Set 1 | atafu village
# Processing Record 49 of Set 1 | stanley
# Processing Record 50 of Set 1 | kavieng
# Processing Record 1 of Set 2 | nueva guinea
# Processing Record 2 of Set 2 | north bend
# Processing Record 3 of Set 2 | basco
# Processing Record 4 of Set 2 | papatowai
# Processing Record 5 of Set 2 | castillos
# Processing Record 6 of Set 2 | alice springs
# Processing Record 7 of Set 2 | rajmahal
# Processing Record 8 of Set 2 | ponta delgada
# Processing Record 9 of Set 2 | leh
# Processing Record 10 of Set 2 | hawaiian paradise park
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | dunedin
# Processing Record 13 of Set 2 | derzhavinsk
# Processing Record 14 of Set 2 | shangri-la
# City not found. Skipping...
# Processing Record 15 of Set 2 | teknaf
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | uturoa
# Processing Record 18 of Set 2 | chernomorskoye
# Processing Record 19 of Set 2 | grand gaube
# Processing Record 20 of Set 2 | tolanaro
# Processing Record 21 of Set 2 | as sulayyil
# Processing Record 22 of Set 2 | masterton
# Processing Record 23 of Set 2 | polyarnyy
# Processing Record 24 of Set 2 | port mathurin
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | dosso
# Processing Record 27 of Set 2 | newman
# Processing Record 28 of Set 2 | huarmey
# Processing Record 29 of Set 2 | ancud
# Processing Record 30 of Set 2 | ola
# Processing Record 31 of Set 2 | thunder bay
# Processing Record 32 of Set 2 | mareeba
# Processing Record 33 of Set 2 | iqaluit
# Processing Record 34 of Set 2 | mahajanga
# Processing Record 35 of Set 2 | kirakira
# Processing Record 36 of Set 2 | mammoth lakes
# Processing Record 37 of Set 2 | balqash
# Processing Record 38 of Set 2 | baardheere
# Processing Record 39 of Set 2 | san antonio de pale
# Processing Record 40 of Set 2 | huinca renanco
# Processing Record 41 of Set 2 | utrik
# Processing Record 42 of Set 2 | namibe
# Processing Record 43 of Set 2 | phan rang-thap cham
# Processing Record 44 of Set 2 | dedougou
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | crane
# Processing Record 47 of Set 2 | kabare
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | vilyuchinsk
# Processing Record 50 of Set 2 | tralee
# Processing Record 1 of Set 3 | portland
# Processing Record 2 of Set 3 | xuddur
# Processing Record 3 of Set 3 | port hedland
# Processing Record 4 of Set 3 | tsengel
# Processing Record 5 of Set 3 | talnakh
# Processing Record 6 of Set 3 | ta`u
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 9 of Set 3 | kemijarvi
# Processing Record 10 of Set 3 | whitehorse
# Processing Record 11 of Set 3 | puerto natales
# Processing Record 12 of Set 3 | ilulissat
# Processing Record 13 of Set 3 | island harbour
# Processing Record 14 of Set 3 | mitu
# Processing Record 15 of Set 3 | saint-pierre
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 18 of Set 3 | hukumati azrah
# Processing Record 19 of Set 3 | tosontsengel
# Processing Record 20 of Set 3 | touros
# Processing Record 21 of Set 3 | sinabang
# Processing Record 22 of Set 3 | lerwick
# Processing Record 23 of Set 3 | nuuk
# Processing Record 24 of Set 3 | rongelap
# Processing Record 25 of Set 3 | mokronog
# Processing Record 26 of Set 3 | jalalpur pirwala
# Processing Record 27 of Set 3 | badger
# Processing Record 28 of Set 3 | belawan
# Processing Record 29 of Set 3 | muynoq
# Processing Record 30 of Set 3 | palmer
# Processing Record 31 of Set 3 | mount pearl
# Processing Record 32 of Set 3 | plymouth
# Processing Record 33 of Set 3 | tubarjal
# Processing Record 34 of Set 3 | college
# Processing Record 35 of Set 3 | mabaruma
# Processing Record 36 of Set 3 | saint-pol-de-leon
# Processing Record 37 of Set 3 | narvik
# Processing Record 38 of Set 3 | magdagachi
# Processing Record 39 of Set 3 | hanover
# Processing Record 40 of Set 3 | coahuayana de hidalgo
# Processing Record 41 of Set 3 | lihue
# Processing Record 42 of Set 3 | kerikeri
# Processing Record 43 of Set 3 | yuanping
# Processing Record 44 of Set 3 | viedma
# Processing Record 45 of Set 3 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 46 of Set 3 | chernyshevsk
# Processing Record 47 of Set 3 | feijo
# Processing Record 48 of Set 3 | el alto
# Processing Record 49 of Set 3 | weno
# Processing Record 50 of Set 3 | broken hill
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | general roca
# Processing Record 3 of Set 4 | ayr
# Processing Record 4 of Set 4 | jardim
# Processing Record 5 of Set 4 | kavaratti
# Processing Record 6 of Set 4 | terni
# Processing Record 7 of Set 4 | katsuura
# Processing Record 8 of Set 4 | menongue
# Processing Record 9 of Set 4 | sao vicente
# Processing Record 10 of Set 4 | moberly
# Processing Record 11 of Set 4 | labytnangi
# Processing Record 12 of Set 4 | aasiaat
# Processing Record 13 of Set 4 | hirara
# Processing Record 14 of Set 4 | bhindar
# Processing Record 15 of Set 4 | afaahiti
# Processing Record 16 of Set 4 | ulsteinvik
# Processing Record 17 of Set 4 | barah
# Processing Record 18 of Set 4 | hilo
# Processing Record 19 of Set 4 | yonago
# Processing Record 20 of Set 4 | cockburn town
# Processing Record 21 of Set 4 | hualien city
# Processing Record 22 of Set 4 | grand falls-windsor
# Processing Record 23 of Set 4 | lanester
# Processing Record 24 of Set 4 | altai
# Processing Record 25 of Set 4 | barra de santo antonio
# Processing Record 26 of Set 4 | palikir - national government center
# Processing Record 27 of Set 4 | hithadhoo
# Processing Record 28 of Set 4 | kourou
# Processing Record 29 of Set 4 | mancio lima
# Processing Record 30 of Set 4 | carutapera
# Processing Record 31 of Set 4 | richards bay
# Processing Record 32 of Set 4 | ascension
# Processing Record 33 of Set 4 | tchintabaraden
# Processing Record 34 of Set 4 | rabo de peixe
# Processing Record 35 of Set 4 | kununurra
# Processing Record 36 of Set 4 | cristalina
# Processing Record 37 of Set 4 | zapolyarnyy
# Processing Record 38 of Set 4 | enewetak
# Processing Record 39 of Set 4 | kaa-khem
# Processing Record 40 of Set 4 | acajutla
# Processing Record 41 of Set 4 | kailua-kona
# Processing Record 42 of Set 4 | namie
# Processing Record 43 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 4 | suda
# Processing Record 45 of Set 4 | haiku-pauwela
# Processing Record 46 of Set 4 | plastun
# Processing Record 47 of Set 4 | toliara
# Processing Record 48 of Set 4 | buchanan
# Processing Record 49 of Set 4 | ialibu
# Processing Record 50 of Set 4 | omutinskiy
# Processing Record 1 of Set 5 | goondiwindi
# Processing Record 2 of Set 5 | happy valley-goose bay
# Processing Record 3 of Set 5 | fale old settlement
# Processing Record 4 of Set 5 | irymple
# Processing Record 5 of Set 5 | dahab
# Processing Record 6 of Set 5 | anadyr
# Processing Record 7 of Set 5 | puerto baquerizo moreno
# Processing Record 8 of Set 5 | avarua
# Processing Record 9 of Set 5 | hurghada
# Processing Record 10 of Set 5 | gandajika
# Processing Record 11 of Set 5 | sakata
# Processing Record 12 of Set 5 | moyale
# Processing Record 13 of Set 5 | sisimiut
# Processing Record 14 of Set 5 | port saint john's
# Processing Record 15 of Set 5 | mala
# Processing Record 16 of Set 5 | daru
# Processing Record 17 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 18 of Set 5 | puerto ayora
# Processing Record 19 of Set 5 | iskateley
# Processing Record 20 of Set 5 | la'ie
# Processing Record 21 of Set 5 | imbituba
# Processing Record 22 of Set 5 | cowra
# Processing Record 23 of Set 5 | rio san juan
# Processing Record 24 of Set 5 | hadibu
# Processing Record 25 of Set 5 | gaalkacyo
# Processing Record 26 of Set 5 | kristiansund
# Processing Record 27 of Set 5 | ciudad bolivar
# Processing Record 28 of Set 5 | udachny
# Processing Record 29 of Set 5 | beloretsk
# Processing Record 30 of Set 5 | antsiranana
# Processing Record 31 of Set 5 | jetiba
# Processing Record 32 of Set 5 | olonkinbyen
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | nizhnesortymskiy
# Processing Record 35 of Set 5 | prokhorovka
# Processing Record 36 of Set 5 | qamdo
# Processing Record 37 of Set 5 | sorada
# Processing Record 38 of Set 5 | cadale
# Processing Record 39 of Set 5 | horsham
# Processing Record 40 of Set 5 | namtsy
# Processing Record 41 of Set 5 | amos
# Processing Record 42 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 43 of Set 5 | rikaze
# Processing Record 44 of Set 5 | rio grande
# Processing Record 45 of Set 5 | port alfred
# Processing Record 46 of Set 5 | rudbar
# Processing Record 47 of Set 5 | ambalangoda
# Processing Record 48 of Set 5 | yuzhno-kurilsk
# Processing Record 49 of Set 5 | florence
# Processing Record 50 of Set 5 | samana
# Processing Record 1 of Set 6 | hwange
# Processing Record 2 of Set 6 | el granada
# Processing Record 3 of Set 6 | sao joao da barra
# Processing Record 4 of Set 6 | usogorsk
# Processing Record 5 of Set 6 | brokopondo
# Processing Record 6 of Set 6 | umm kaddadah
# Processing Record 7 of Set 6 | manaure
# Processing Record 8 of Set 6 | saipan
# Processing Record 9 of Set 6 | qaqortoq
# Processing Record 10 of Set 6 | broome
# Processing Record 11 of Set 6 | gueltat zemmour
# City not found. Skipping...
# Processing Record 12 of Set 6 | pemangkat
# Processing Record 13 of Set 6 | bolivar
# Processing Record 14 of Set 6 | timimoun
# Processing Record 15 of Set 6 | susuman
# Processing Record 16 of Set 6 | ust'-barguzin
# Processing Record 17 of Set 6 | benguela
# Processing Record 18 of Set 6 | balabac
# Processing Record 19 of Set 6 | mogadishu
# Processing Record 20 of Set 6 | decorah
# Processing Record 21 of Set 6 | zhangye
# Processing Record 22 of Set 6 | malango
# Processing Record 23 of Set 6 | coxen hole
# Processing Record 24 of Set 6 | livno
# Processing Record 25 of Set 6 | kiama
# Processing Record 26 of Set 6 | sittwe
# Processing Record 27 of Set 6 | karoi
# Processing Record 28 of Set 6 | vorgashor
# Processing Record 29 of Set 6 | safford
# Processing Record 30 of Set 6 | nemuro
# Processing Record 31 of Set 6 | igarka
# Processing Record 32 of Set 6 | wailua homesteads
# Processing Record 33 of Set 6 | st. john's
# Processing Record 34 of Set 6 | vernon
# Processing Record 35 of Set 6 | aketi
# Processing Record 36 of Set 6 | flin flon
# Processing Record 37 of Set 6 | arauco
# Processing Record 38 of Set 6 | mormugao
# Processing Record 39 of Set 6 | zangguy
# City not found. Skipping...
# Processing Record 40 of Set 6 | erenhot
# Processing Record 41 of Set 6 | okhotsk
# Processing Record 42 of Set 6 | ridgecrest
# Processing Record 43 of Set 6 | woolgoolga
# Processing Record 44 of Set 6 | detroit lakes
# Processing Record 45 of Set 6 | kendari
# Processing Record 46 of Set 6 | vadso
# Processing Record 47 of Set 6 | tangalle
# Processing Record 48 of Set 6 | nishinoomote
# Processing Record 49 of Set 6 | rio verde de mato grosso
# Processing Record 50 of Set 6 | laguna
# Processing Record 1 of Set 7 | tazovsky
# Processing Record 2 of Set 7 | prabumulih
# Processing Record 3 of Set 7 | turgen
# Processing Record 4 of Set 7 | la passe
# Processing Record 5 of Set 7 | hasaki
# Processing Record 6 of Set 7 | sandnessjoen
# Processing Record 7 of Set 7 | mount gambier
# Processing Record 8 of Set 7 | taro
# Processing Record 9 of Set 7 | las tablas
# Processing Record 10 of Set 7 | south hedland
# Processing Record 11 of Set 7 | sur
# Processing Record 12 of Set 7 | klyuchi
# Processing Record 13 of Set 7 | san antonio oeste
# Processing Record 14 of Set 7 | sao gabriel da cachoeira
# Processing Record 15 of Set 7 | isafjordur
# Processing Record 16 of Set 7 | carnarvon
# Processing Record 17 of Set 7 | westport
# Processing Record 18 of Set 7 | pingliang
# Processing Record 19 of Set 7 | kapa'a
# Processing Record 20 of Set 7 | humaita
# Processing Record 21 of Set 7 | robertsport
# Processing Record 22 of Set 7 | saldanha
# Processing Record 23 of Set 7 | pundong
# Processing Record 24 of Set 7 | santa ana
# Processing Record 25 of Set 7 | nadi
# Processing Record 26 of Set 7 | dongning
# Processing Record 27 of Set 7 | barabai
# Processing Record 28 of Set 7 | codrington
# Processing Record 29 of Set 7 | yazykovo
# Processing Record 30 of Set 7 | chivhu
# Processing Record 31 of Set 7 | camden
# Processing Record 32 of Set 7 | itoman
# Processing Record 33 of Set 7 | west island
# Processing Record 34 of Set 7 | sao jose da coroa grande
# Processing Record 35 of Set 7 | el sauzal de rodriguez
# Processing Record 36 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 37 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 38 of Set 7 | tsiombe
# Processing Record 39 of Set 7 | lobujya
# Processing Record 40 of Set 7 | ciudad lazaro cardenas
# Processing Record 41 of Set 7 | concepcion
# Processing Record 42 of Set 7 | ilha de mocambique
# Processing Record 43 of Set 7 | san patricio
# Processing Record 44 of Set 7 | thompson
# Processing Record 45 of Set 7 | wagar
# Processing Record 46 of Set 7 | kingston
# Processing Record 47 of Set 7 | gobabis
# Processing Record 48 of Set 7 | shirahamacho-usazakiminami
# Processing Record 49 of Set 7 | bafoulabe
# Processing Record 50 of Set 7 | san pedro pochutla
# Processing Record 1 of Set 8 | arraial do cabo
# Processing Record 2 of Set 8 | kyzyl
# Processing Record 3 of Set 8 | mersing
# Processing Record 4 of Set 8 | hamilton
# Processing Record 5 of Set 8 | juneau
# Processing Record 6 of Set 8 | homeland park
# Processing Record 7 of Set 8 | mbandaka
# Processing Record 8 of Set 8 | tabou
# Processing Record 9 of Set 8 | lhokseumawe
# Processing Record 10 of Set 8 | orange farm
# Processing Record 11 of Set 8 | san roque
# Processing Record 12 of Set 8 | ves'yegonsk
# Processing Record 13 of Set 8 | nampula
# Processing Record 14 of Set 8 | wajir
# Processing Record 15 of Set 8 | yarmouth
# Processing Record 16 of Set 8 | eirunepe
# Processing Record 17 of Set 8 | massawa
# Processing Record 18 of Set 8 | northam
# Processing Record 19 of Set 8 | tarko-sale
# Processing Record 20 of Set 8 | pangkalanbuun
# Processing Record 21 of Set 8 | pacific grove
# Processing Record 22 of Set 8 | fort st. john
# Processing Record 23 of Set 8 | bodo
# Processing Record 24 of Set 8 | ambovombe
# Processing Record 25 of Set 8 | puerto colombia
# Processing Record 26 of Set 8 | urangan
# Processing Record 27 of Set 8 | halden
# Processing Record 28 of Set 8 | sigli
# Processing Record 29 of Set 8 | at taj
# Processing Record 30 of Set 8 | port macquarie
# Processing Record 31 of Set 8 | cidreira
# Processing Record 32 of Set 8 | mambajao
# Processing Record 33 of Set 8 | bealanana
# Processing Record 34 of Set 8 | gettorf
# Processing Record 35 of Set 8 | las vegas
# Processing Record 36 of Set 8 | tazacorte
# Processing Record 37 of Set 8 | batang
# Processing Record 38 of Set 8 | guymon
# Processing Record 39 of Set 8 | gebeit
# Processing Record 40 of Set 8 | santa ana de yacuma
# Processing Record 41 of Set 8 | vila velha
# Processing Record 42 of Set 8 | tokar
# Processing Record 43 of Set 8 | georgiyevka
# Processing Record 44 of Set 8 | christchurch
# Processing Record 45 of Set 8 | zaio
# Processing Record 46 of Set 8 | antofagasta
# Processing Record 47 of Set 8 | west mackay
# Processing Record 48 of Set 8 | nuku'alofa
# Processing Record 49 of Set 8 | bubaque
# Processing Record 50 of Set 8 | port lincoln
# Processing Record 1 of Set 9 | catia la mar
# Processing Record 2 of Set 9 | chake chake
# Processing Record 3 of Set 9 | nakamura
# Processing Record 4 of Set 9 | jieshi
# Processing Record 5 of Set 9 | putyvl'
# Processing Record 6 of Set 9 | hagere maryam
# Processing Record 7 of Set 9 | nar'yan-mar
# Processing Record 8 of Set 9 | nizhneangarsk
# Processing Record 9 of Set 9 | camayenne
# Processing Record 10 of Set 9 | north bay
# Processing Record 11 of Set 9 | san felice sul panaro
# Processing Record 12 of Set 9 | camarinas
# Processing Record 13 of Set 9 | kalmunai
# Processing Record 14 of Set 9 | meadow lake
# Processing Record 15 of Set 9 | gunjur
# Processing Record 16 of Set 9 | peace river
# Processing Record 17 of Set 9 | auki
# Processing Record 18 of Set 9 | jalai nur
# Processing Record 19 of Set 9 | magog
# Processing Record 20 of Set 9 | ulladulla
# Processing Record 21 of Set 9 | kurchatov
# Processing Record 22 of Set 9 | hudson
# Processing Record 23 of Set 9 | amga
# Processing Record 24 of Set 9 | salistea de sus
# Processing Record 25 of Set 9 | wau
# Processing Record 26 of Set 9 | abepura
# Processing Record 27 of Set 9 | takoradi
# Processing Record 28 of Set 9 | gadzhiyevo
# Processing Record 29 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 30 of Set 9 | ludlow
# Processing Record 31 of Set 9 | santa marta
# Processing Record 32 of Set 9 | whakatane
# Processing Record 33 of Set 9 | al kharijah
# Processing Record 34 of Set 9 | ghat
# Processing Record 35 of Set 9 | prince george
# Processing Record 36 of Set 9 | watampone
# Processing Record 37 of Set 9 | kawalu
# Processing Record 38 of Set 9 | bandarbeyla
# Processing Record 39 of Set 9 | alexandria
# Processing Record 40 of Set 9 | bontang
# Processing Record 41 of Set 9 | buka
# Processing Record 42 of Set 9 | maktar
# Processing Record 43 of Set 9 | calvinia
# Processing Record 44 of Set 9 | maua
# Processing Record 45 of Set 9 | kachug
# Processing Record 46 of Set 9 | oamaru
# Processing Record 47 of Set 9 | twon-brass
# Processing Record 48 of Set 9 | prachuap khiri khan
# Processing Record 49 of Set 9 | francisco beltrao
# Processing Record 50 of Set 9 | la gi
# Processing Record 1 of Set 10 | nianzishan
# Processing Record 2 of Set 10 | peterhead
# Processing Record 3 of Set 10 | xilin hot
# Processing Record 4 of Set 10 | springbok
# Processing Record 5 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 6 of Set 10 | bereeda
# Processing Record 7 of Set 10 | san andros
# City not found. Skipping...
# Processing Record 8 of Set 10 | aykol
# City not found. Skipping...
# Processing Record 9 of Set 10 | kol'chugino
# Processing Record 10 of Set 10 | alva
# Processing Record 11 of Set 10 | juuka
# Processing Record 12 of Set 10 | khanty-mansiysk
# Processing Record 13 of Set 10 | gamba
# Processing Record 14 of Set 10 | dzuunharaa
# Processing Record 15 of Set 10 | mugia
# Processing Record 16 of Set 10 | labrador city
# Processing Record 17 of Set 10 | ilhabela
# Processing Record 18 of Set 10 | akrehamn
# Processing Record 19 of Set 10 | coquimbo
# Processing Record 20 of Set 10 | yuci
# Processing Record 21 of Set 10 | dombarovskiy
# Processing Record 22 of Set 10 | huangshan
# Processing Record 23 of Set 10 | brak
# Processing Record 24 of Set 10 | lusambo
# Processing Record 25 of Set 10 | kokofata
# City not found. Skipping...
# Processing Record 26 of Set 10 | zaigrayevo
# Processing Record 27 of Set 10 | noosa heads
# Processing Record 28 of Set 10 | bansi
# Processing Record 29 of Set 10 | kolwezi
# Processing Record 30 of Set 10 | bellmere
# Processing Record 31 of Set 10 | rio claro
# Processing Record 32 of Set 10 | am djarass
# City not found. Skipping...
# Processing Record 33 of Set 10 | luderitz
# Processing Record 34 of Set 10 | holualoa
# Processing Record 35 of Set 10 | maracaibo
# Processing Record 36 of Set 10 | santa rita
# Processing Record 37 of Set 10 | tezu
# Processing Record 38 of Set 10 | nieuw nickerie
# Processing Record 39 of Set 10 | poronaysk
# Processing Record 40 of Set 10 | moengo
# Processing Record 41 of Set 10 | merizo village
# Processing Record 42 of Set 10 | kirriemuir
# Processing Record 43 of Set 10 | minas de marcona
# Processing Record 44 of Set 10 | grevena
# Processing Record 45 of Set 10 | kushiro
# Processing Record 46 of Set 10 | new norfolk
# Processing Record 47 of Set 10 | kill devil hills
# Processing Record 48 of Set 10 | kadhan
# Processing Record 49 of Set 10 | selkirk
# Processing Record 50 of Set 10 | safotu
# Processing Record 1 of Set 11 | olyokminsk
# Processing Record 2 of Set 11 | spelle
# Processing Record 3 of Set 11 | singaraja
# Processing Record 4 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 5 of Set 11 | argo
# Processing Record 6 of Set 11 | puerto san jose
# Processing Record 7 of Set 11 | anchau
# Processing Record 8 of Set 11 | puerto aysen
# Processing Record 9 of Set 11 | camacupa
# Processing Record 10 of Set 11 | craigavon
# Processing Record 11 of Set 11 | newport
# Processing Record 12 of Set 11 | badagry
# Processing Record 13 of Set 11 | naze
# Processing Record 14 of Set 11 | nantucket
# Processing Record 15 of Set 11 | mundri
# Processing Record 16 of Set 11 | keflavik
# Processing Record 17 of Set 11 | conception bay south
# Processing Record 18 of Set 11 | kapuskasing
# Processing Record 19 of Set 11 | egilsstadir
# Processing Record 20 of Set 11 | tabas
# Processing Record 21 of Set 11 | remire-montjoly
# Processing Record 22 of Set 11 | icano
# Processing Record 23 of Set 11 | usinsk
# Processing Record 24 of Set 11 | cassia
# Processing Record 25 of Set 11 | colonia
# Processing Record 26 of Set 11 | prado
# Processing Record 27 of Set 11 | beacon square
# Processing Record 28 of Set 11 | huatabampo
# Processing Record 29 of Set 11 | bolgatanga
# Processing Record 30 of Set 11 | dong ha
# Processing Record 31 of Set 11 | piacabucu
# Processing Record 32 of Set 11 | bembereke
# Processing Record 33 of Set 11 | gurupi
# Processing Record 34 of Set 11 | kualakapuas
# Processing Record 35 of Set 11 | la peca
# Processing Record 36 of Set 11 | mil'kovo
# Processing Record 37 of Set 11 | hluti
# Processing Record 38 of Set 11 | jhelum
# Processing Record 39 of Set 11 | leiyang
# Processing Record 40 of Set 11 | allapalli
# Processing Record 41 of Set 11 | saryozek
# Processing Record 42 of Set 11 | mejit
# Processing Record 43 of Set 11 | yerofey pavlovich
# Processing Record 44 of Set 11 | mermoz boabab
# Processing Record 45 of Set 11 | porto velho
# Processing Record 46 of Set 11 | le vauclin
# Processing Record 47 of Set 11 | tvoroyri
# Processing Record 48 of Set 11 | inyati
# Processing Record 49 of Set 11 | gaffney
# Processing Record 50 of Set 11 | canet de mar
# Processing Record 1 of Set 12 | zaysan
# Processing Record 2 of Set 12 | ulimang
# Processing Record 3 of Set 12 | brookings
# Processing Record 4 of Set 12 | maputo
# Processing Record 5 of Set 12 | indianola
# Processing Record 6 of Set 12 | paka
# Processing Record 7 of Set 12 | george town
# Processing Record 8 of Set 12 | saint-philippe
# Processing Record 9 of Set 12 | marcala
# Processing Record 10 of Set 12 | verkh-chebula
# Processing Record 11 of Set 12 | arinos
# Processing Record 12 of Set 12 | mezocsat
# Processing Record 13 of Set 12 | odoyev
# Processing Record 14 of Set 12 | mirnyy
# Processing Record 15 of Set 12 | mao
# Processing Record 16 of Set 12 | yeniseysk
# Processing Record 17 of Set 12 | yangquan
# Processing Record 18 of Set 12 | berdigestyakh
# Processing Record 19 of Set 12 | taoudenni
# Processing Record 20 of Set 12 | saint-joseph
# Processing Record 21 of Set 12 | nova sintra
# Processing Record 22 of Set 12 | la rinconada
# Processing Record 23 of Set 12 | gunnison
# Processing Record 24 of Set 12 | kolyvan'
# Processing Record 25 of Set 12 | limbang
# Processing Record 26 of Set 12 | itaituba
# Processing Record 27 of Set 12 | salumbar
# Processing Record 28 of Set 12 | lazaro cardenas
# Processing Record 29 of Set 12 | zahedan
# Processing Record 30 of Set 12 | hami
# Processing Record 31 of Set 12 | kamloops
# Processing Record 32 of Set 12 | alofi
# Processing Record 33 of Set 12 | maxixe
# Processing Record 34 of Set 12 | lospalos
# Processing Record 35 of Set 12 | luanda
# Processing Record 36 of Set 12 | boa vista
# Processing Record 37 of Set 12 | kzyltu
# Processing Record 38 of Set 12 | izamal
# Processing Record 39 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 40 of Set 12 | novyy urgal
# Processing Record 41 of Set 12 | onega
# Processing Record 42 of Set 12 | nishifukuma
# Processing Record 43 of Set 12 | arrifes
# ------------------------------------------------
# Data Retrieval Complete
# ------------------------------------------------

# %%
# Convert raw data to dataframe.
city_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})

# Drop any cities that were skipped because they could not be found using the OpenWeatherMap API.
city_weather_df = city_weather_df.dropna(how="any")
print(city_weather_df.count())
# Out:
# City          573
# Lat           573
# lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Export the city data into a .csv file.
city_weather_df.to_csv("../output_data/city_weather_data.csv", index=False)
cities.to_csv("../output_data/cities.csv", index=False)
# Display the DataFrame
weather_df = pd.read_csv("../output_data/city_weather_data.csv")

weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Export the city data into a .csv file.
#       2 city_weather_df.to_csv("../output_data/city_weather_data.csv", index=False)
# ----> 3 cities.to_csv("../output_data/cities.csv", index=False)
#       4 # Display the DataFrame
#       5 weather_df = pd.read_csv("../output_data/city_weather_data.csv")
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
date_time = datetime.date(datetime.now())
# Create a scatter plot for latitude vs max temperature.
x_values = weather_df['Lat']
y_values = weather_df['Max Temp']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"City Latitude vs Max Temperature {date_time}")
plt.grid()
plt.savefig("../output_data/latitude_vs_temperature.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Create a scatter plot for latitude vs humidity.
x_values = weather_df['Lat']
y_values = weather_df['Humidity']
fig1, ax1 = plt.subplots(figsize=(10, 8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity {date_time}')
plt.grid()
plt.savefig("../output_data/latitude_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Create a scatter plot for latitude vs cloudiness.
x_values = weather_df['Lat']
y_values = weather_df['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness {date_time}')
plt.grid()
plt.savefig("../output_data/latitude_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs wind speed.
x_values = weather_df['Lat']
y_values = weather_df['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed {date_time}')
plt.grid()
plt.savefig("../output_data/latitude_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def createLinearRegressionPlot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
      # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    fig1, ax1 = plt.subplots(figsize=(10,8))
    plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
    plt.xlabel(x_label,fontsize = 14)
    plt.ylabel(y_label,fontsize = 14)
    if ylim is not None:
        plt.ylim(0, ylim)
    today = datetime.date(datetime.now())
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} {today}",fontsize = 15)
    plt.annotate(line_eq,xy=(10, 50),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(-50, 40),fontsize=22,xycoords='data',xytext=(0.4, 0.3), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(10, 25),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    # Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    return plt.plot(x_values,regress_values,"r-")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] >= 0]

# Display sample data
northern_hemisphere_weather_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] < 0]

# Display sample data
southern_hemisphere_weather_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Max Temp']
createLinearRegressionPlot(x_values, y_values, "Lat", "Max Temp (F)", "Northern",(0, 0))
plt.savefig("../output_data/Northern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))

plt.savefig("../output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Create a scatter plot for latitude vs humditiy (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(40, 20))
plt.savefig("../output_data/Northern_Hemisphere_Humidity_Latitude_Linear.png", bbox_inches="tight")
plt.show()

# %%
# Create a scatter plot for latitude vs humditiy (southern hemisphere)
x_values1 = southern_hemisphere_weather_df['Lat']
y_values1 = southern_hemisphere_weather_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(40, 20), 150)
plt.savefig("../output_data/southern_humudity_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Create a scatter plot for latitude vs cloudiness (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Northern",(30, 50))

plt.savefig("../output_data/Northern Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
plt.savefig("../output_data/Southern_Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Create a scatter plot for latitude vs wind speed(northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))
plt.savefig("../output_data/Northern_Hemisphere_Wind_Speed_Latitude_Lin.png", bbox_inches="tight")
plt.show()

# %%
# Create a scatter plot for latitude vs wind speed (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)
plt.savefig("../output_data/Southern_Hemisphere_Wind_Speed_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
